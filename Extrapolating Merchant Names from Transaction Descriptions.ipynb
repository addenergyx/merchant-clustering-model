# %% [markdown]
# # Extrapolating Merchant Names from Transaction Descriptions using ML

# %% [markdown]
# In my [data engineering project](https://github.com/addenergyx/cashback-data-pipeline), I faced a significant challenge: multiple inconsistent merchant names recorded across transaction data.
# This inconsistency hindered the ability to accurately group transactions, complicating further analysis.
# Given the vast amount of data, manually correcting these discrepancies was impractical.
# To address this, I decided to explore the potential of machine learning to automate the process.
# An unsupervised clustering model was chosen, which is particularly suited for this task because it does not require labeled data, making it feasible to implement across large datasets without prior tagging.
# This approach promises to streamline the preprocessing of transaction data, enhancing the accuracy of the analytical outputs.

# %%
import pandas as pd
from collections import Counter
from sklearn.cluster import KMeans
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# Data has already been preprocessed by the ELT script in the data pipeline [here](https://github.com/addenergyx/cashback-data-pipeline/blob/main/glue_job/elt.py)

# %%
data = pd.read_csv('data.csv')

# %%
data.head()
# Out:
#                               reward_id                        transaction_id  \
# 0  a299489c-ce6e-40ba-a6d7-026a90e4a510  3e02ef10-9f41-4fd5-9dd1-5b03c455bd96
# 1  3c2fe1f5-c9e1-46e1-941f-00f120abf2d2  fda003db-154a-47e6-8d24-21ab43317814
# 2  bcc75323-94e8-472b-9feb-d09f89405b7c  030b3eba-0aaf-4b33-861f-a2c93109e204
# 3  a01090ad-174c-49ef-9a0e-4b87e5badbdd  32f63642-f1c7-4af7-8753-5deb8ee8dd7d
# 4  245ca1ed-8af6-4a4c-9a15-62acdf260f29  15996a4b-87c6-47c6-b855-419b477a1c87
#
#               description  plu_amount transaction_date  available reason  \
# 0      CURVE SUBSCRIPTION    2.262443       2024-03-23      False    NaN
# 1  CRV*PIZZA HUT AIPC HIG    0.304554       2024-03-17      False    NaN
# 2  CRV*SN Gat Airport SST    0.147938       2024-03-17      False    NaN
# 3  CRV*M S SIMPLY FOOD SS    0.075356       2024-03-17      False    NaN
# 4   CRV*adidas UK Limited    0.579151       2024-03-17      False    NaN
#
#                          created_at                        updated_at  \
# 0  2024-03-25 06:43:56.024000+00:00  2024-03-25 06:43:56.024000+00:00
# 1  2024-03-19 06:20:47.865000+00:00  2024-03-19 06:20:47.865000+00:00
# 2  2024-03-19 06:20:47.630000+00:00  2024-03-19 06:20:47.630000+00:00
# 3  2024-03-19 06:20:47.462000+00:00  2024-03-19 06:20:47.462000+00:00
# 4  2024-03-19 06:20:47.065000+00:00  2024-03-19 06:20:47.065000+00:00
#
#    rebate_rate  fiat_amount_rewarded currency      reference_type  \
# 0            0                1000.0      GBP  perk_830246_reward
# 1            5                3143.0      GBP   fiat_transactions
# 2            5                1435.0      GBP   fiat_transactions
# 3            5                 740.0      GBP   fiat_transactions
# 4            5                6000.0      GBP   fiat_transactions
#
#                  reward_type  amount   plu_price  transaction_amount
# 0  DAILY_REBATE_DISTRIBUTION -1799.0  442.000002               17.99
# 1  DAILY_REBATE_DISTRIBUTION -3143.0  516.000006               31.43
# 2  DAILY_REBATE_DISTRIBUTION -1435.0  485.000014               14.35
# 3  DAILY_REBATE_DISTRIBUTION  -740.0  491.000036                7.40
# 4  DAILY_REBATE_DISTRIBUTION -6000.0  518.000008               60.00

# %%
len(data['description'].unique())
# Out:
# 431

# %% [markdown]
# ## Transaction dataset review and further preprocessing

# %% [markdown]
# Transactions made with a Curve card will appear as CRV* – “Merchant Name” (for example: CRV* – Starbucks) on bank statements.

# %%
data['description'] = data['description'].astype(str)
data['description'] = data['description'].apply(lambda x: x.replace('CRV*', ''))
data['description'] = data['description'].apply(lambda x: x.replace('ZILCH*', ''))

# %%
df2 = data.loc[data['description'] != None]

description_trends = {}

most_common = {}

for ind in df2.index:
    description = df2['description'][ind]
    if description in description_trends:
        description_trends[description] += 1 
    else:
        description_trends[description] = 1
    most_common = Counter(description_trends).most_common(50)

# %%
most_common
# Out:
# [('Klarna, London, GB CD 4309', 512),
#  ('Klarna', 338),
#  ('ZILCH., London, GB CD 4309', 121),
#  ('ARCADE CAFE, London, GB CD 4309', 13),
#  ('UBR* PENDING.UBER.COM, London, GB CD 4309', 12),
#  ('CURVE SUBSCRIPTION, 00012, LONDON, GB CD 4309', 10),
#  ('Cinnabar, London, GB CD 4309', 9),
#  ('CURVE SUBSCRIPTION', 8),
#  ('APPLE.COM BILL, London, GB CD 4309', 8),
#  ('AWS EMEA, London, GB CD 4309', 8),
#  ('WAIPO EAT STOCK, London, GB CD 4309', 8),
#  ('BUTLINS CENTRE STAGE, London, GB CD 4309', 8),
#  ('adidas UK Limited', 6),
#  ('AIRTIME REWARDS LTD, London, GB CD 4309', 6),
#  ('AIRTIME REWARDS LTD, 00025, MANCHESTER, GB CD 4309', 6),
#  ('DRAPER ARMS, London, GB CD 4309', 6),
#  ('WAYBETTER  INC., London, GB CD 4309', 6),
#  ('ASDA CS LTD MONKSWOOD', 5),
#  ('Audible UK', 5),
#  ('ASDA CS LTD\\MONKSWOOD', 5),
#  ('ASDA CS LTD, London, GB CD 4309', 5),
#  ('Trainline, London, GB CD 4309', 5),
#  ('CINEWORLD, London, GB CD 4309', 5),
#  ('SLUG   LETTUCE   POPW, London, GB CD 4309', 5),
#  ('TESCO PFS 3891, London, GB CD 4309', 5),
#  ('BOUNCE OLD STREET, London, GB CD 4309', 5),
#  ('TEWINBURY FARM HOUSE, London, GB CD 4309', 5),
#  ('BUTLINS BAR ROSSO, London, GB CD 4309', 5),
#  ('APPLE.COM/BILL', 4),
#  ('APPLE.COM BILL Hollyh', 4),
#  ('ASDA CS LTD', 4),
#  ('JADE GARDEN, London, GB CD 4309', 4),
#  ('EXPERIAN UK, London, GB CD 4309', 4),
#  ('Best Wrap In Town, London, GB CD 4309', 4),
#  ('TESCO PFS 4195, London, GB CD 4309', 4),
#  ('Cineworld, London, GB CD 4309', 4),
#  ('MCDONALDS, London, GB CD 4309', 4),
#  ('TfL Travel Charge, London, GB CD 4309', 4),
#  ('HERTZ 24 7, London, GB CD 4309', 4),
#  ('BUTLINS HOTSHOTS, London, GB CD 4309', 4),
#  ('COSTCO PFS CANENDISH', 3),
#  ('EXPERIAN UK', 3),
#  ('MCDONALDS-JBR MURJAN-', 3),
#  ('AIRTIME REWARDS LTD', 3),
#  ('AMZNMktplace', 3),
#  ('COSTCO PFS', 3),
#  ('COSTCO PFS, London, GB CD 4309', 3),
#  ('HOME BARGAINS, London, GB CD 4309', 3),
#  ('Spotify UK, London, GB CD 4309', 3),
#  ('Zettle_*FAKE FESTIVAL, London, GB CD 4309', 3)]

# %%
# Possible merchant names from descriptions
merchant_keywords = [
    'TESCO', 'ASDA', 'COSTCO', 'SPOTIFY', 'AMAZON', 'APPLE', 'NIKE', 'ADIDAS',
    'KFC', 'MCDONALDS', 'SAINSBURYS', 'PIZZA HUT', 'UBER', 'PAYPAL', 'EBAY',
    'ARGOS', 'BOOTS', 'HERMES', 'JADE GARDEN', 'CINNABAR', 'ZILCH', 'KLARNA', 'BUTLINS', 'CINEWORLD'
    'CURVE', 'AIRTIME REWARDS'
]

# %%
# Function to extract merchant name from description
def extract_merchant(description):
    description = description.upper()
    for keyword in merchant_keywords:
        if keyword in description:
            return keyword
    return description  # Fallback category for unmatched descriptions

# %%
data['merchant_name'] = data['description'].apply(extract_merchant)

# %%
data.head()
# Out:
#                               reward_id                        transaction_id  \
# 0  a299489c-ce6e-40ba-a6d7-026a90e4a510  3e02ef10-9f41-4fd5-9dd1-5b03c455bd96
# 1  3c2fe1f5-c9e1-46e1-941f-00f120abf2d2  fda003db-154a-47e6-8d24-21ab43317814
# 2  bcc75323-94e8-472b-9feb-d09f89405b7c  030b3eba-0aaf-4b33-861f-a2c93109e204
# 3  a01090ad-174c-49ef-9a0e-4b87e5badbdd  32f63642-f1c7-4af7-8753-5deb8ee8dd7d
# 4  245ca1ed-8af6-4a4c-9a15-62acdf260f29  15996a4b-87c6-47c6-b855-419b477a1c87
#
#           description  plu_amount transaction_date  available reason  \
# 0  CURVE SUBSCRIPTION    2.262443       2024-03-23      False    NaN
# 1  PIZZA HUT AIPC HIG    0.304554       2024-03-17      False    NaN
# 2  SN Gat Airport SST    0.147938       2024-03-17      False    NaN
# 3  M S SIMPLY FOOD SS    0.075356       2024-03-17      False    NaN
# 4   adidas UK Limited    0.579151       2024-03-17      False    NaN
#
#                          created_at                        updated_at  \
# 0  2024-03-25 06:43:56.024000+00:00  2024-03-25 06:43:56.024000+00:00
# 1  2024-03-19 06:20:47.865000+00:00  2024-03-19 06:20:47.865000+00:00
# 2  2024-03-19 06:20:47.630000+00:00  2024-03-19 06:20:47.630000+00:00
# 3  2024-03-19 06:20:47.462000+00:00  2024-03-19 06:20:47.462000+00:00
# 4  2024-03-19 06:20:47.065000+00:00  2024-03-19 06:20:47.065000+00:00
#
#    rebate_rate  fiat_amount_rewarded currency      reference_type  \
# 0            0                1000.0      GBP  perk_830246_reward
# 1            5                3143.0      GBP   fiat_transactions
# 2            5                1435.0      GBP   fiat_transactions
# 3            5                 740.0      GBP   fiat_transactions
# 4            5                6000.0      GBP   fiat_transactions
#
#                  reward_type  amount   plu_price  transaction_amount  \
# 0  DAILY_REBATE_DISTRIBUTION -1799.0  442.000002               17.99
# 1  DAILY_REBATE_DISTRIBUTION -3143.0  516.000006               31.43
# 2  DAILY_REBATE_DISTRIBUTION -1435.0  485.000014               14.35
# 3  DAILY_REBATE_DISTRIBUTION  -740.0  491.000036                7.40
# 4  DAILY_REBATE_DISTRIBUTION -6000.0  518.000008               60.00
#
#         merchant_name
# 0  CURVE SUBSCRIPTION
# 1           PIZZA HUT
# 2  SN GAT AIRPORT SST
# 3  M S SIMPLY FOOD SS
# 4              ADIDAS

# %%
data.isnull().sum()
# Out:
# reward_id                0
# transaction_id           0
# description              0
# plu_amount               0
# transaction_date         0
# available                0
# reason                  48
# created_at               0
# updated_at               0
# rebate_rate              0
# fiat_amount_rewarded     0
# currency                 0
# reference_type           0
# reward_type              0
# amount                   0
# plu_price                0
# transaction_amount       0
# merchant_name            0
# dtype: int64

# %%
data['merchant_name'].unique()
# Out:
# array(['CURVE SUBSCRIPTION', 'PIZZA HUT', 'SN GAT AIRPORT SST',
#        'M S SIMPLY FOOD SS', 'ADIDAS', 'STOCKX MARKETPLACE NL', 'PAYPAL',
#        'EXPERIAN UK NOTTIN', 'BOOHOO.COM UK LTD', 'RENDERCOM 14158304',
#        'NANDOSCOUK 4420839', 'CKMNORD VPNCOM GBR', 'BRITISH A 35314369',
#        'NIKE', 'STEVENAGE BOROUGH', 'COLLECTION POTUNIT',
#        'YUM BAOFLAT 16, WE', 'MCDONALDS', 'AMAZON', 'AMZNMKTPLACE1 PRIN',
#        'EBAY', 'SPOTIFY', 'OFFICE', 'HOME BARGAINS STEV',
#        'RIU HOTELS AND RES', 'SIZE?', 'APPLE', 'COSTCO',
#        'DART CHARGE AUTO TOP', 'HEROKU* JAN 921682', 'EXPERIAN UKEXPERIA',
#        'TESCO', 'TRAINLINETRAINLINE', 'AWS EMEA38 AVENUE',
#        'TOOTH CLUB STEVENA', 'ALDI 40 776 FAIRLA', 'BARBICAN EVENTS LT',
#        'WHITE HART - HERTF', 'CLOUD 396VQR', 'TRAINLINE.COM LOND',
#        'JUMBO UK LTD LONDO', 'WANIS INTERNATIONA', 'NSPPD LAGOS NGA',
#        'GOOGLE*CLOUD TKJLW', 'STEVENAGE STEVENAG', 'NSPPD LAGOS LAGOS',
#        'JADE GARDEN', 'CINNABAR', 'SUMUP *DIRTIES 61',
#        'PARKING EYE OLD HA', 'RTI*NECTAR HOTELS', 'JUSTGIVING GUIDEDO',
#        'SP YULIFE REWARDS', 'AEROPORT BARCELONA', 'L OVELLA NEGRA BARCEL',
#        "MERY'S MARKET BARCELO", 'VIDAL PONS S A BARCEL',
#        'SHOKO BARCELONA ESP', 'HARD ROCK BARCELONA B',
#        'METRO BARCELONA BARCE', 'SSP UK LTD LUTON GBR',
#        'HERTZ 24 7 MIDDLESEX', 'DUNELM SOFTFURNISHING', 'SAINSBURYS',
#        'EXPERIAN UK', 'BK 7871 13KFR9 LEIDSE', 'NORTON GREEN CAR CENT',
#        'ARGOS', 'BOOTS', 'ASDA', 'CLOUD 3MDFXC', 'AMZNMKTPLACE 1 PRINCI',
#        'DELIVEROO', 'SP HERA CLOTHING', 'FARFETCH*FARFETCH', 'HERMES',
#        'AUDIBLE UK', 'POUNDLAND LTD - 2247', 'REVOLUTION DERBY NO 1',
#        'NAN', 'FREEDOM SPORTSLINE LTD', 'CLOUD DXWLJS', 'FLANNELS',
#        'DOUBLETREE BY HILTON NOTT', 'AIRTIME REWARDS', 'UBER',
#        'AMZNMKTPLACE', 'RYANAIR', 'TRAINLINE', 'KLARNA',
#        'TSB RETURNS LTD', 'OB* LUMIN', 'VICTORIA FISH BAR 3-4',
#        'EXPERIAN UK NOTTINGHA', 'GOOGLE*CLOUD WZBPH6 C',
#        'ICELAND - 1709 - STEV', "DOMINO'S PIZZA",
#        'AUDIBLE UK\\1 WASHINGT', 'BARBICAN EVENTS LTD\\T',
#        'EMMA APP\\49-51 CENTRA', 'EXPERIAN UK\\EXPERIAN',
#        'GOOGLE *YOUTUBEPREMIU', 'NLOVWRJVWLW4LMD5P4\\UN',
#        'HASTY TASTY PIZZA', 'THE SILVER ARCH 1188',
#        'AFAS LIVE\\JOHAN CRUIJ', 'GALL  GALL 6547', 'ALBERT HEIJN 1001',
#        'VEGAN TEMPLE BAR\\LANG', 'NS SCHIPHOL', 'TIER AE 9-18269',
#        'WAGAMAMA LIMITED 224', 'TRAINLINE\\HOLBORN 120',
#        'CAPITAL ONE\\TRENT HOU', 'STAR GROCERIES',
#        'HOOTERS, LONDON, GB CD 4309', 'BIERKELLER, LONDON, GB CD 4309',
#        'DUNKIN, LONDON, GB CD 4309',
#        'STAR GROCERIES 01, LONDON, GB CD 4309',
#        'HOME BARGAINS, LONDON, GB CD 4309',
#        'CURVE SUBSCRIPTION, 00012, LONDON, GB CD 4309',
#        'SIZE, LONDON, GB CD 4309', 'LUVNATURAL SALON, LONDON, GB CD 4309',
#        'LEONARDO HTL NOTTINGH, LONDON, GB CD 4309',
#        'ZETTLE_*FAKE FESTIVAL, LONDON, GB CD 4309',
#        'LOUNGEKEY, LONDON, GB CD 4309',
#        'STANDING ORDER, LONDON, GB CD 4309',
#        'BINGOL KEBAB, LONDON, GB CD 4309',
#        'EXPERIAN UK, LONDON, GB CD 4309',
#        'ALDI STORES LIMITED, LONDON, GB CD 4309',
#        'TRAINLINE, LONDON, GB CD 4309',
#        'BEST WRAP IN TOWN, LONDON, GB CD 4309',
#        'GOOGLE*CLOUD D8PMHK, LONDON, GB CD 4309',
#        'WEMBLEY PARK, LONDON, GB CD 4309',
#        'STAR GROCERIES, LONDON, GB CD 4309',
#        'AUDIBLE UK, LONDON, GB CD 4309',
#        'MULBERRY TREE, LONDON, GB CD 4309',
#        'POST OFFICE COUNTER, LONDON, GB CD 4309',
#        'CINEWORLD, LONDON, GB CD 4309',
#        'PITCHER   PIANO, LONDON, GB CD 4309',
#        'GOOGLE *YOUTUBEPREMIU, LONDON, GB CD 4309',
#        'DOLPHIN FITNESS LIMIT, LONDON, GB CD 4309',
#        'OLD TOWN FISH BAR, LONDON, GB CD 4309',
#        'SLUG   LETTUCE   POPW, LONDON, GB CD 4309',
#        'GOOGLE*CLOUD TFL7MT, LONDON, GB CD 4309',
#        'TSGN, LONDON, GB CD 4309', 'THE O2 ARENA, LONDON, GB CD 4309',
#        'DRINK N SINK, LONDON, GB CD 4309',
#        'BARRIO WATFORD, LONDON, GB CD 4309',
#        'PRIME BURGER ST PANCR, LONDON, GB CD 4309',
#        'SPAR WARMOESSTRAAT, LONDON, GB CD 4309',
#        'SSP UK LTD, LONDON, GB CD 4309',
#        'NORTON GREEN CAR CENT, LONDON, GB CD 4309',
#        'EASYJET DNATA IN FLIG, LONDON, GB CD 4309',
#        'RENES CROISSANTERIE, LONDON, GB CD 4309',
#        'NS SCHIPHOL, LONDON, GB CD 4309',
#        'T K MAXX LTD, LONDON, GB CD 4309',
#        'SHELL WATFORD ROAD, LONDON, GB CD 4309',
#        'NANDOS GATWICK SOUTH, LONDON, GB CD 4309',
#        'MERPAGO*COCOBONGO, LONDON, GB CD 4309',
#        'HOTEL RIU CANCUN, LONDON, GB CD 4309',
#        'DAFFODIL MULLIGAN, LONDON, GB CD 4309',
#        'ARRIVA KENT THAMESIDE, LONDON, GB CD 4309',
#        'LUTON AIRPORT BK LS, LONDON, GB CD 4309',
#        'NS AMSTERDAM AMSTEL, LONDON, GB CD 4309',
#        'THE HAPPY PIG, LONDON, GB CD 4309',
#        'CCV*EPISODE CHAPTER 3, LONDON, GB CD 4309',
#        'AH TO GO 5817, LONDON, GB CD 4309',
#        'SMART FORMATIONS, LONDON, GB CD 4309', 'ZILCH',
#        'GUACAMOLE, LONDON, GB CD 4309', 'CINCO SOLES, LONDON, GB CD 4309',
#        'AEROPUERTO MADRID BAR, LONDON, GB CD 4309',
#        'WICKES BISHOP STORTFO, LONDON, GB CD 4309',
#        'CO-OP GROUP FOOD RETA, LONDON, GB CD 4309',
#        'GOOGLE YOUTUBEPREMIUM, LONDON, GB CD 4309',
#        'DRAPER ARMS, LONDON, GB CD 4309',
#        'SP MANIERE DE VOIR, LONDON, GB CD 4309',
#        'AWS EMEA, LONDON, GB CD 4309',
#        'GOOGLE*CLOUD 446W5G, LONDON, GB CD 4309',
#        'APCOA PARKING UK, LONDON, GB CD 4309',
#        'DAVID LLOYD LEISURE L, LONDON, GB CD 4309',
#        'WAYBETTER  INC., LONDON, GB CD 4309',
#        'DART-CHARGE, LONDON, GB CD 4309',
#        'ULTRATICKETS.CO.UK, LONDON, GB CD 4309',
#        'ZETTLE_*ATIS OLD STRE, LONDON, GB CD 4309',
#        'STEVENAGE BOROUGH COU, LONDON, GB CD 4309',
#        'RODIZIO RICO, LONDON, GB CD 4309',
#        'JUSTGIVING CANCERRESE, LONDON, GB CD 4309',
#        'TIER SE RIDE, LONDON, GB CD 4309',
#        'SUBWAY KUNGSGATAN, LONDON, GB CD 4309',
#        'ESPRESSO H 267, LONDON, GB CD 4309',
#        'VASAMUSEETS ENTRE, LONDON, GB CD 4309',
#        'BASSTARD B 1527, LONDON, GB CD 4309',
#        'WH SMITH STANST, LONDON, GB CD 4309',
#        'WAIPO EAT STOCK, LONDON, GB CD 4309',
#        'GREASY SPOON, LONDON, GB CD 4309',
#        'ZETTLE_*TAXI, LONDON, GB CD 4309',
#        'KELLYS BAR, LONDON, GB CD 4309',
#        'MCD 002 - STHLM, LONDON, GB CD 4309',
#        'MCD 008 - STHLM, LONDON, GB CD 4309',
#        'V50 RESTAURANG, LONDON, GB CD 4309',
#        'MCD 003 - S T E, LONDON, GB CD 4309',
#        'NOSH AND CHOW, LONDON, GB CD 4309',
#        'EAST 4 AB, LONDON, GB CD 4309',
#        'TIER SE 2-36761, LONDON, GB CD 4309',
#        'HM SE0187, LONDON, GB CD 4309',
#        'ZETTLE_*THE GOOD GRIN, LONDON, GB CD 4309',
#        'HMSHOST ARLANDA AIRPO, LONDON, GB CD 4309',
#        'STN WDF MAIN, LONDON, GB CD 4309',
#        'BURGER KING, LONDON, GB CD 4309',
#        'UNHCR REFUGEE AGENCY, LONDON, GB CD 4309',
#        'CHICKEN GEORGE, LONDON, GB CD 4309',
#        'SP HTLT SUPPS, LONDON, GB CD 4309',
#        'ROYAL MAIL GROUP LTD, LONDON, GB CD 4309',
#        'GOOGLE*CLOUD XW75QM, LONDON, GB CD 4309',
#        'ULTRA EVENTS, LONDON, GB CD 4309',
#        'DAVID LLOYD LEISURE S, LONDON, GB CD 4309',
#        'CITY TREE LTD, LONDON, GB CD 4309',
#        'TFL TRAVEL CHARGE, LONDON, GB CD 4309',
#        'BOUNCE OLD STREET, LONDON, GB CD 4309',
#        'SIMMONS BAR, LONDON, GB CD 4309',
#        'LEEDS - PRYZM, LONDON, GB CD 4309',
#        'HOTEL IBIS, LONDON, GB CD 4309',
#        'URBAN EXPRESS 1131214, LONDON, GB CD 4309',
#        'LEEDS STATION LEON 12, LONDON, GB CD 4309',
#        'PROARK UK HOTELS LTD, LONDON, GB CD 4309',
#        'TFL TRAVEL CH VICTORI, LONDON, GB CD 4309',
#        'HOTELSCOM724568295292, LONDON, GB CD 4309',
#        'AMZNMKTPLACE, LONDON, GB CD 4309',
#        'HYDE PARK HOTEL LEEDS, LONDON, GB CD 4309',
#        'THERME NORD BUCURESTI, LONDON, GB CD 4309',
#        'THREE HORSESHOES, LONDON, GB CD 4309',
#        'MANAHATTA HEADINGLEY, LONDON, GB CD 4309',
#        'VERY, LONDON, GB CD 4309',
#        'SUMUP  *LINDLEY EDUCA, LONDON, GB CD 4309',
#        'TOOTH CLUB, LONDON, GB CD 4309',
#        'SP YULIFE REWARDS, LONDON, GB CD 4309',
#        'PERKS AT WORK, LONDON, GB CD 4309',
#        'WILKO RETAIL LIMITED, LONDON, GB CD 4309',
#        'HM HENNES  MAURITZ U, LONDON, GB CD 4309',
#        'GOOGLE*CLOUD TT42VW, LONDON, GB CD 4309',
#        'MANAHATTA MERRION STR, LONDON, GB CD 4309',
#        'SQUARE PIZZA STATION, LONDON, GB CD 4309',
#        'ELECTRIC SHUFFLE LIMI, LONDON, GB CD 4309',
#        'CARGO LEEDS, LONDON, GB CD 4309',
#        'NANDOS.CO.UK, LONDON, GB CD 4309',
#        'ALEXANDRA PALACE TRAD, LONDON, GB CD 4309',
#        'JURYS INN NOTTINGHAM, LONDON, GB CD 4309',
#        'MARKS SPENCER PLC SAC, LONDON, GB CD 4309',
#        'UPS LTD, LONDON, GB CD 4309',
#        'THE SHOREDITCH, LONDON, GB CD 4309',
#        'OLD STREET RECORDS, LONDON, GB CD 4309',
#        'PHOENIX BAR, LONDON, GB CD 4309',
#        'SUMUP  *MY TAXIS, LONDON, GB CD 4309',
#        'TRAFIK, LONDON, GB CD 4309',
#        'ZETTLE_*BUTCHIES LTD, LONDON, GB CD 4309',
#        'HUNGER CURE FISH AND, LONDON, GB CD 4309',
#        'RED LION, LONDON, GB CD 4309',
#        'THE VOUCHER MARKET LT, LONDON, GB CD 4309',
#        'JUST EAT, LONDON, GB CD 4309',
#        'NOTTINGHAM HILTON, LONDON, GB CD 4309',
#        'TFL COVENT GARDEN, LONDON, GB CD 4309',
#        'WRP MANAGEMENT LIMITE, LONDON, GB CD 4309', 'KFC',
#        'JB PARTNERS PUB, LONDON, GB CD 4309',
#        'TEWINBURY FARM HOUSE, LONDON, GB CD 4309',
#        'SUMUP  *HABIB UR REHM, LONDON, GB CD 4309',
#        'WWW.SLL.CO.UK STEVENA, LONDON, GB CD 4309',
#        'CAPITAL ONE, LONDON, GB CD 4309', 'STEVENAGE, LONDON, GB CD 4309',
#        'SUBWAY 41980 THE FORU, LONDON, GB CD 4309',
#        'AIRPORT LOUNGE VISIT, LONDON, GB CD 4309',
#        'RYANAIR INFLIGHT, LONDON, GB CD 4309',
#        'BONGIORNO OTOPENI 3, LONDON, GB CD 4309',
#        'DNATA CATERING S.A., LONDON, GB CD 4309',
#        'HMSHOST UK LIMITED, LONDON, GB CD 4309',
#        'CITY CAFE EXPRESS SRL, LONDON, GB CD 4309',
#        'LAVAZZA, LONDON, GB CD 4309',
#        'GYROS THESSALONIKIS C, LONDON, GB CD 4309',
#        'ARCADE CAFE, LONDON, GB CD 4309', 'PH DELTA, LONDON, GB CD 4309',
#        'BOLT.EU R 2212100225, LONDON, GB CD 4309',
#        'PREMIER RESTAURANTS R, LONDON, GB CD 4309',
#        'BOLT.EU R 2212100312, LONDON, GB CD 4309',
#        'YACHT CLUB 4, LONDON, GB CD 4309',
#        'BOLT.EU R 2212091231, LONDON, GB CD 4309',
#        'MELISSA EXPRESS SRL, LONDON, GB CD 4309',
#        'XCLUSIVE GRILLCREPES, LONDON, GB CD 4309',
#        'HERTZ 24 7, LONDON, GB CD 4309', 'BUTLINS',
#        'SE TONBRIDGE SST, LONDON, GB CD 4309',
#        'CROWDCUBE* CHIP, LONDON, GB CD 4309',
#        'HEROKU *JUL-69615089, LONDON, GB CD 4309',
#        'GOOGLE*CLOUD 4MPXVS, LONDON, GB CD 4309',
#        'POUNDLAND LTD, LONDON, GB CD 4309',
#        'ZETTLE_*ESPRESS ORGAN, LONDON, GB CD 4309',
#        'ZETTLE_*SMOKIN  ACES, LONDON, GB CD 4309',
#        'SWINGERS CRAZY GOLF, LONDON, GB CD 4309',
#        'ZETTLE_*SHACK FOOD, LONDON, GB CD 4309',
#        'MS* IBIZAROCKSHOTEL, LONDON, GB CD 4309',
#        'EAST ASIA FOOD, LONDON, GB CD 4309',
#        'CANALHOUSE, LONDON, GB CD 4309',
#        'ZETTLE_*ROXY BALL ROO, LONDON, GB CD 4309',
#        'CURED, LONDON, GB CD 4309',
#        'WING STOP NOTTINGHAM, LONDON, GB CD 4309',
#        'POPEYES LOUISIANA CHI, LONDON, GB CD 4309',
#        'HEALTHYWAGE, LONDON, GB CD 4309',
#        'DRIVER RETRAINING COU, LONDON, GB CD 4309',
#        'MOVEMBER FOUNDATION, LONDON, GB CD 4309',
#        'ZTL*MARKET CAFE, LONDON, GB CD 4309',
#        'GOOGLE *SERVICES, LONDON, GB CD 4309',
#        'THE ISKELE, LONDON, GB CD 4309',
#        'WATFORD CENTRE LIMITE, LONDON, GB CD 4309'], dtype=object)

# %%
len(data['merchant_name'].unique())
# Out:
# 314

# %%
# Encode merchant names
label_encoder = LabelEncoder()
merchant_labels = label_encoder.fit_transform(data['merchant_name'])

# %%
# K-Means clustering, one cluster per unique merchant
kmeans = KMeans(n_clusters=len(label_encoder.classes_), random_state=42)
kmeans.fit(merchant_labels.reshape(-1, 1))
data['cluster'] = kmeans.labels_

# %%
# Analyze clusters
transaction_counts = data.groupby(['cluster', 'merchant_name']).size().reset_index(name='Number of Transactions')
sample_descriptions = data.groupby(['cluster', 'merchant_name'])['description'].apply(
    lambda x: x.sample(min(len(x), 5))).reset_index().rename(columns={'level_2': 'original_index'})
detailed_cluster_info = pd.merge(transaction_counts, sample_descriptions, on=['cluster', 'merchant_name'])

# %%
pd.set_option('display.max_columns', None)
detailed_cluster_info
# Out:
#      cluster                              merchant_name  \
# 0          0              HM SE0187, LONDON, GB CD 4309
# 1          1                            TSB RETURNS LTD
# 2          2                                    BUTLINS
# 3          2                                    BUTLINS
# 4          2                                    BUTLINS
# ..       ...                                        ...
# 517      309      VASAMUSEETS ENTRE, LONDON, GB CD 4309
# 518      310          AH TO GO 5817, LONDON, GB CD 4309
# 519      311                         YUM BAOFLAT 16, WE
# 520      312           WEMBLEY PARK, LONDON, GB CD 4309
# 521      313  ARRIVA KENT THAMESIDE, LONDON, GB CD 4309
#
#      Number of Transactions  original_index  \
# 0                         1            1126
# 1                         1             144
# 2                        28            1572
# 3                        28            1586
# 4                        28            1580
# ..                      ...             ...
# 517                       1            1095
# 518                       1             871
# 519                       1              19
# 520                       1             713
# 521                       1             864
#
#                                    description
# 0                HM SE0187, London, GB CD 4309
# 1                              TSB Returns Ltd
# 2     BUTLINS CENTRE STAGE, London, GB CD 4309
# 3        BUTLINS BAR ROSSO, London, GB CD 4309
# 4      BUTLINS BURGER KING, London, GB CD 4309
# ..                                         ...
# 517      VASAMUSEETS ENTRE, London, GB CD 4309
# 518          Ah To Go 5817, London, GB CD 4309
# 519                         Yum baoFlat 16, We
# 520           WEMBLEY PARK, London, GB CD 4309
# 521  ARRIVA KENT THAMESIDE, London, GB CD 4309
#
# [522 rows x 5 columns]

# %%
detailed_cluster_info.to_csv('clusters.csv')
